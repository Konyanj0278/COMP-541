# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head(10)
# Out:
#                       ADDRESS            CITY  ZIP OR POSTAL CODE      PRICE  \
# 0          10556 mountair Ave         Tujunga             91042.0   449000.0
# 1            14093 Bayside Dr         Norwalk             90650.0   299000.0
# 2         141 S Clark Dr #315  West Hollywood             90048.0   498000.0
# 3       20327 Saticoy St #211        Winnetka             91306.0   260000.0
# 4              2110 Barry Ave     Los Angeles             90025.0  1949000.0
# 5           2843-2845 Rosanna     Los Angeles             90039.0  1599000.0
# 6               29 Marion Ave        Pasadena             91106.0  2495000.0
# 7    3734 S Canfield Ave #106     Los Angeles             90034.0   399000.0
# 8       4914-4912 Mendota Ave     Los Angeles             90042.0  1550000.0
# 9  618-624.5 E Chevy Chase Dr        Glendale             91205.0  3775000.0
#
#    BEDS  BATHS  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 0   0.0    0.0       6800.0    6800.0         0.0             2.0
# 1   0.0    1.0        477.0  143136.0      1976.0            55.0
# 2   0.0    1.0        480.0   40236.0      1973.0            14.0
# 3   0.0    1.0        440.0       0.0      1978.0             3.0
# 4   0.0    0.0          0.0    6194.0         0.0            95.0
# 5   0.0    0.0       2089.0    7037.0      1929.0            49.0
# 6   0.0    0.0       5290.0    7999.0      1912.0            96.0
# 7   0.0    1.0        454.0       0.0      1972.0            24.0
# 8   0.0    0.0       1794.0    4802.0      1924.0            19.0
# 9   0.0    0.0       7580.0   21218.0      1951.0           249.0
#
#    $/SQUARE FEET HOA/MONTH
# 0           66.0     $0.00
# 1          627.0   $365.00
# 2         1038.0   $383.00
# 3          591.0   $184.00
# 4            0.0     $0.00
# 5          765.0     $0.00
# 6          472.0     $0.00
# 7          879.0   $424.00
# 8          864.0     $0.00
# 9          498.0     $0.00

# %%
df.describe()
# Out:
#        ZIP OR POSTAL CODE         PRICE         BEDS        BATHS  \
# count         1259.000000  1.259000e+03  1259.000000  1259.000000
# mean         90570.718030  1.828084e+06     4.179508     3.144559
# std            548.275735  2.515356e+06     4.122087     2.942776
# min          90001.000000  4.990000e+04     0.000000     0.000000
# 25%          90048.000000  7.999935e+05     2.000000     2.000000
# 50%          90404.000000  1.190000e+06     3.000000     2.500000
# 75%          91104.000000  1.999000e+06     4.000000     3.750000
# max          91803.000000  4.500000e+07    55.000000    48.000000
#
#         SQUARE FEET      LOT SIZE   YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET
# count   1259.000000  1.259000e+03  1259.000000     1259.000000   1.259000e+03
# mean    2451.820492  2.374837e+04  1930.562351       33.833995   2.626887e+03
# std     2520.484814  7.419857e+04   240.937675       62.317194   5.629040e+04
# min        0.000000  0.000000e+00     0.000000        0.000000   0.000000e+00
# 25%     1266.500000  5.237000e+03  1936.000000        3.000000   5.025000e+02
# 50%     1786.000000  6.803000e+03  1956.000000       10.000000   6.510000e+02
# 75%     2819.500000  1.169750e+04  1979.500000       37.000000   8.650000e+02
# max    34291.000000  1.244628e+06  2022.000000      615.000000   1.950000e+06

# %%
df.count()
# Out:
# ADDRESS               1259
# CITY                  1259
# ZIP OR POSTAL CODE    1259
# PRICE                 1259
# BEDS                  1259
# BATHS                 1259
# SQUARE FEET           1259
# LOT SIZE              1259
# YEAR BUILT            1259
# DAYS ON MARKET        1259
# $/SQUARE FEET         1259
# HOA/MONTH             1259
# dtype: int64

# %%
df.mode()
# Out:
#   ADDRESS         CITY  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  \
# 0       0  Los Angeles             90019.0  850000.0   3.0    2.0
#
#    SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET HOA/MONTH
# 0          0.0       0.0      1924.0             3.0            0.0     $0.00

# %%
Q1= df.quantile(0.25)
Q3= df.quantile(0.75)
IQR= Q3-Q1
IQR
# Out:
# ZIP OR POSTAL CODE       1056.00
# PRICE                 1199006.50
# BEDS                        2.00
# BATHS                       1.75
# SQUARE FEET              1553.00
# LOT SIZE                 6460.50
# YEAR BUILT                 43.50
# DAYS ON MARKET             34.00
# $/SQUARE FEET             362.50
# HOA/MONTH                 107.50
# Unnamed: 12                  NaN
# Unnamed: 13                  NaN
# Unnamed: 14                 0.00
# dtype: float64

# %%
#sns.kdeplot(df['ADDRESS'])
#sns.kdeplot(df['CITY'])
#sns.kdeplot(df['ZIP OR POSTAL CODE'])
#sns.kdeplot(df['BEDS'])
#sns.kdeplot(df['PRICE'])
#sns.kdeplot(df['BATHS'])
#sns.kdeplot(df['LOT SIZE'])
#sns.kdeplot(df['$/SQUARE FEET'])
sns.kdeplot(df['HOA/MONTH'])
# Out:
# <AxesSubplot:xlabel='HOA/MONTH', ylabel='Density'>

# %%
skew=df.skew()
skew
# Out:
# ZIP OR POSTAL CODE     0.648362
# PRICE                  8.700488
# BEDS                   5.819840
# BATHS                  6.215015
# SQUARE FEET            6.103178
# LOT SIZE               8.467379
# YEAR BUILT            -7.773858
# DAYS ON MARKET         4.156265
# $/SQUARE FEET         33.332161
# HOA/MONTH              4.706897
# Unnamed: 12                 NaN
# Unnamed: 13                 NaN
# Unnamed: 14                 NaN
# dtype: float64

# %%
class_counts= df.groupby('PRICE').agg('LOT SIZE').agg('BEDS').aggs('BATHS').size()
class_counts
# Out:
# PRICE
# 49900.0       1
# 68500.0       1
# 70000.0       1
# 80000.0       2
# 82500.0       1
#              ..
# 16998000.0    1
# 21500000.0    2
# 25999000.0    1
# 37500000.0    1
# 45000000.0    1
# Name: LOT SIZE, Length: 629, dtype: int64
